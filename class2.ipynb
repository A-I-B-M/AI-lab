# %%
print('hello')
# Out:
# hello

# %%
l = [1, 2,3, [2, 3], 'hehe']

# %%
l
del l[-1]

# %%
for c in l:
    print(c)

for i in range(len(l)):
  print(l[i])
# Out:
# 1
# 2
# 3
# [2, 3]
# 1
# 2
# 3
# [2, 3]

# %%
d = {
    1 : "hello",
    'a' : 2,
    2 : [1, 2, 1 ,2],
    3 : "Ai lab",
    "name" : "ABM",
    (1,2,3): "DSA"
}

# %%
for i in d:
    print(i, "Value = ", d[i])
# Out:
# 1 Value =  hello
# a Value =  2
# 2 Value =  [1, 2, 1, 2]
# 3 Value =  Ai lab
# name Value =  ABM
# (1, 2, 3) Value =  DSA

# %%
random ="aaabbbb"

# print(set(random))

# %%
randoms = "Ami bhat khai"
dis={}
for i in randoms :
    if i not in dis:
        dis[i] = 0
    dis[i] += 1
print(dis)
# Out:
# {'A': 1, 'm': 1, 'i': 2, ' ': 2, 'b': 1, 'h': 2, 'a': 2, 't': 1, 'k': 1}

# %%
# OOP (class)

# %%
class student :
    def __init__(self, name):
        self.name = name
    def print_info(self):
        print(self.name)

# %%
s1 = student("Amd")


s1.print_info()  # Output: Amd
# Out:
# Amd

# %%
import numpy as np

# %%
arr = [1,2,3,4,5]
type(arr)
# Out:
# list

# %%
arr = np.array(arr)
type(arr)
# Out:
# numpy.ndarray

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(arr.shape)
# Out:
# (5,)

# %%
a = [
    [1,2],
    [3,4]
]
a = np.array(a)
print(a.shape)
# Out:
# (2, 2)

# %%
arr = 10 * np.random.random((2,2))
arr
# Out:
# array([[7.11117706, 2.058264  ],
#        [4.2495935 , 0.51172003]])

# %%
#np.zero -> all 0
#np.one -> all 1

arr = np.eye(3)
print(arr)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
arr = np.random.randint(1, 10, (3, 3))
arr2 = np.random.randint(1, 10, (3, 3))
print(arr)
print(arr2)
# Out:
# [[6 1 3]
#  [1 7 8]
#  [7 6 4]]
# [[4 2 3]
#  [1 2 1]
#  [7 8 1]]

# %%
arr + arr2
# r = np.sum(arr,arr2)
# r = np.subtract(arr,arr2)
# r = np.multiply(arr,arr2)
print(np.dot(arr, arr2))
# Out:
# [[46 38 22]
#  [67 80 18]
#  [62 58 31]]

# %%
arr
# Out:
# array([[6, 1, 3],
#        [1, 7, 8],
#        [7, 6, 4]], dtype=int32)

# %%
arr[0:2,:]
# Out:
# array([[6, 1, 3],
#        [1, 7, 8]], dtype=int32)

# %%
arr[0:2, :1]
# Out:
# array([[6],
#        [1]], dtype=int32)

# %%
#sum of all element
np.sum(arr)
# Out:
# np.int64(43)

# %%
#sum of all rows
np.sum(arr, axis = 0)
# Out:
# array([14, 14, 15])

# %%
#sum  of all colums
np.sum(arr, axis = 1)
# Out:
# array([10, 16, 17])

# %%
#Re shape
arr = np.random.random((3, 4))
arr
# Out:
# array([[0.14444712, 0.3022922 , 0.55693054, 0.98163824],
#        [0.58111535, 0.71507706, 0.33596201, 0.60660345],
#        [0.94280521, 0.30759318, 0.68751171, 0.24300066]])

# %%
arr=np.reshape(arr,(4 , 3))
arr
# Out:
# array([[0.14444712, 0.3022922 , 0.55693054],
#        [0.98163824, 0.58111535, 0.71507706],
#        [0.33596201, 0.60660345, 0.94280521],
#        [0.30759318, 0.68751171, 0.24300066]])

# %%
#MatplotLib
import matplotlib.pyplot as plt

# %%
import math

x = np.arange(0, 3*np.pi, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = x*x

# %%
plt.plot(x, y1, 'pink')
plt.plot(x, y2, 'red')

plt.plot(x, y3, 'green')

plt.legend(["sin", "cos"])
plt.show()

# %%
# TEST /// if else,, loop , fundtion,, list,, dictionary,,, 
# numpy ,, matplotlib
